# %%
from zipfile import ZipFile
import pandas as pd
import numpy as np

# %% [markdown]
# # Загрузка данных

# %%
def gen_parcer(f):
    for line in f.readlines():
        yield line.decode().strip().split("\t")

# %%
with ZipFile('data.zip') as datazip:
    with datazip.open('train.tsv') as f:
        pd_train = pd.DataFrame(gen_parcer(f),
                                columns=["context_id", "context_2", "context_1", "context_0", "reply_id", "reply",
                                         "label", "confidence"])
    with datazip.open('public.tsv') as f:
         pd_public = pd.DataFrame(gen_parcer(f),
                                  columns=["context_id", "context_2", "context_1", "context_0", "reply_id", "reply"])

# %%
pd_train.head()
# Out:
#     context_id                                          context_2  \
# 0  22579918886  кликни на меня а потом на надпись " видео - зв...
# 1  22579918886  кликни на меня а потом на надпись " видео - зв...
# 2  22579918886  кликни на меня а потом на надпись " видео - зв...
# 3  22579918886  кликни на меня а потом на надпись " видео - зв...
# 4  22579918886  кликни на меня а потом на надпись " видео - зв...
#
#            context_1                context_0 reply_id  \
# 0  о , я тебя вижу .  ладно , повесь трубку .        0
# 1  о , я тебя вижу .  ладно , повесь трубку .        1
# 2  о , я тебя вижу .  ладно , повесь трубку .        2
# 3  о , я тебя вижу .  ладно , повесь трубку .        3
# 4  о , я тебя вижу .  ладно , повесь трубку .        4
#
#                       reply    label    confidence
# 0                 не могу .     good  0.8753516175
# 1    нет , звонить буду я .  neutral  0.9009682113
# 2  слушай , я не мог уйти .      bad  0.8843202145
# 3   я не прекращу звонить .     good  0.9825304673
# 4              я звоню им .     good  0.8380535096

# %%
pd_public.head()
# Out:
#      context_id                                          context_2 context_1  \
# 0  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 1  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 2  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 3  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 4  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
#
#   context_0 reply_id               reply
# 0     нет ?        0               неа .
# 1     нет ?        1     нет , не хочу .
# 2     нет ?        2               нет .
# 3     нет ?        3     конечно , нет .
# 4     нет ?        4  разумеется , нет .

# %%
pd_train.count()
# Out:
# context_id    97533
# context_2     97533
# context_1     97533
# context_0     97533
# reply_id      97533
# reply         97533
# label         97533
# confidence    97533
# dtype: int64

# %%
pd_public.count()
# Out:
# context_id    9968
# context_2     9968
# context_1     9968
# context_0     9968
# reply_id      9968
# reply         9968
# dtype: int64

# %%
target_encoder = {'bad': 0, 'good': 2, 'neutral': 1}  
pd_train.label = pd_train.label.map(target_encoder)

# %%
pd_data = pd.concat([pd_train, pd_public], axis=0).reset_index(drop=True)
pd_data.label.fillna(-1, inplace=True)
pd_data.confidence.fillna(0.0, inplace=True)

# %% [markdown]
# # Что за данные

# %%
pd_train.shape, pd_public.shape, pd_data.shape
# Out:
# ((97533, 8), (9968, 6), (107501, 8))

# %%
pd_data.groupby("label")["context_id"].count() / len(pd_data)
# Out:
# label
# -1.0    0.092725
#  0.0    0.323439
#  1.0    0.104687
#  2.0    0.479149
# Name: context_id, dtype: float64

# %% [markdown]
# # Простой бейзлайн

# %%
import pickle

# %%
import re

# %% [markdown]
# w2v_fpath = "w2v/tenth.norm-sz500-w7-cb0-it5-min5.w2v"
# w2v = gensim.models.KeyedVectors.load_word2vec_format(w2v_fpath, binary=True, unicode_errors='ignore')
# w2v.init_sims(replace=True)

# %%
w2v = pickle.load(open("w2v/w2vs.pickle", "rb"))

# %%
s_words = pd_data[["context_2", "context_1", "context_0", "reply"]] \
    .apply(lambda x: " ".join(x), axis=1)

# %%
def clean_text(x):
    x = x.lower()
    x = x.replace("ё", "е")
    return x

# %%
empty_vector = np.zeros(500)
def condext_to_vec(x):
    words = re.findall(r"\b(\w+)\b", clean_text(x))
    vectors = sum([w2v[word] for word in words if word in w2v])
    return (empty_vector + vectors).reshape(1, -1)

# %%
def not_in_vec(x):
    words = re.findall(r"\b([a-zа-я]+)\b", clean_text(x))
    words = [word for word in words if word not in w2v]
    return " ".join(words)

# %%
s_strange = s_words.apply(not_in_vec)

# %%
len(s_strange[~s_strange.eq("")])
# Out:
# 1084

# %%
s_words.loc[2600]
# Out:
# 'ќе шучу . " ты разрешишь мне вернутьс€ в тюрьму ? я начинаю уставать , это так унизительно . когда я возбуждаюсь , я издаю такого рода звуки . раньше ты не лаял .'

# %%
s_strange[~s_strange.eq("")]
# Out:
# 193         вудхалл
# 624          фабрей
# 867           ворус
# 868           ворус
# 869           ворус
# 870           ворус
# 871           ворус
# 872           ворус
# 1109         волмов
# 1110         волмов
# 1111         волмов
# 1112         волмов
# 1113         волмов
# 1114         волмов
# 1952       эрствайл
# 2166          дэнно
# 2346         гендзи
# 2549       оливерио
# 3025        огустин
# 3026        огустин
# 3027        огустин
# 3028        огустин
# 3029        огустин
# 3030        огустин
# 3232         изобэл
# 3301         тоетие
# 3302         тоетие
# 3303         тоетие
# 3304         тоетие
# 3305         тоетие
#             ...
# 104418     костанза
# 104419     костанза
# 104420     кастиэль
# 104455        тофер
# 104730        дэнно
# 105017      ротстин
# 105711         шадо
# 105874       пиджей
# 105875       пиджей
# 105876       пиджей
# 105877       пиджей
# 105878       пиджей
# 105879       пиджей
# 106052    сулбаимеи
# 106053        cэнди
# 106075      адалинд
# 106277      погугли
# 106284          тьi
# 106849     скиттеры
# 106850     скиттеры
# 106851     скиттеры
# 106852     скиттеры
# 106853     скиттеры
# 106854     скиттеры
# 107289        бичум
# 107290        бичум
# 107291        бичум
# 107292        бичум
# 107293        бичум
# 107294        бичум
# Length: 1084, dtype: object

# %% [markdown]
# ## features

# %%
def to_features_w2v(df):
    s_words = df[["context_2", "context_1", "context_0"]].apply(lambda x: " ".join(x), axis=1)
    context = np.concatenate(s_words.apply(condext_to_vec).tolist())
    
    s_words = df["reply"]
    reply = np.concatenate(s_words.apply(condext_to_vec).tolist())
    
    features = np.concatenate([context, reply], axis=1)
    return features

# %% [markdown]
# ## crossval

# %%
from tqdm import tqdm_notebook

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=3)

# %%
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_absolute_error

# %%
def calc_ndcg_score(df, y_predict):
    df = df.copy()
    df["predict"] = y_predict
    #dcg
    df.sort_values(["context_id", "predict"], ascending=[True, False], inplace=True)
    df["row_count"] = df.groupby("context_id").cumcount()+1
    df["dcg"] = df["label"] / np.log2(df["row_count"] + 1)
    #idcg
    df.sort_values(["context_id", "label"], ascending=[True, False], inplace=True)
    df["row_count"] = df.groupby("context_id").cumcount()+1
    df["idcg"] = df["label"] / np.log2(df["row_count"] + 1)
    
    df_context = df.groupby("context_id").sum()
    return (df_context["dcg"] / df_context["idcg"]).mean() * 100000

# %%
def do_cross_val(model_reg, to_features, to_target, model_fit_params=None):
    mae_errors = []
    ndcg_scores = []

    for _train, _test in tqdm_notebook(skf.split(pd_train.index, pd_train.label), total=3):
        i_train = pd_train.iloc[_train]
        i_test = pd_train.iloc[_test]

        X_train = to_features(i_train)
        X_test = to_features(i_test)
        Y_train = to_target(i_train)
        Y_test = to_target(i_test)

        model_reg.load_weights("model_nn.w")
        model_reg.fit(X_train, Y_train, **model_fit_params)
        Y_predict = model_reg.predict(X_test)
        mae_errors.append(mean_absolute_error(Y_test, Y_predict))
        ndcg_scores.append(calc_ndcg_score(i_test, Y_predict))

    print(mae_errors)
    print(ndcg_scores)

# %% [markdown]
# ## target

# %%
trg_label = lambda x: x.label.values

# %%
trg_label_confidence = lambda x: (x.label.values - 1) * x.confidence.values.astype(np.float)

# %% [markdown]
# ## Нормальные варианты

# %%
do_cross_val(LinearRegression(), to_features_w2v, trg_label)
# Out:
# A Jupyter Widget
# [0.82638449406819026, 0.82574022422909588, 0.82666949630383568]
# [86306.57817832676, 86285.70686972419, 86404.02531996512]

# %%
do_cross_val(LinearRegression(), to_features_w2v, trg_label_confidence)
# Out:
# A Jupyter Widget
# [0.71481938513885968, 0.71375232297887958, 0.71354418000758502]
# [86336.8461095529, 86280.83807429724, 86467.65361220425]

# %% [markdown]
# # Сеточка

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM, Dropout

# %%
model = Sequential([
    Dense(1000, input_dim=1000),
    Activation('relu'),
    Dropout(0.5),
    Dense(50),
    Activation('relu'),
    Dense(1),
    Activation('linear'),
])

model.compile(optimizer='adam',
              loss='mean_squared_error')
model.save_weights("model_nn.w")

# %%
do_cross_val(model, to_features_w2v, trg_label_confidence,
            {"epochs": 10, "batch_size": 256, "verbose": 2, "validation_split": 0.1})
# Out:
# A Jupyter Widget
# Train on 58518 samples, validate on 6503 samples
# Epoch 1/10
#  - 18s - loss: 0.6488 - val_loss: 0.6246
# Epoch 2/10
#  - 17s - loss: 0.6253 - val_loss: 0.6176
# Epoch 3/10
#  - 19s - loss: 0.6180 - val_loss: 0.6142
# Epoch 4/10
#  - 19s - loss: 0.6115 - val_loss: 0.6090
# Epoch 5/10
#  - 18s - loss: 0.6064 - val_loss: 0.6122
# Epoch 6/10
#  - 17s - loss: 0.6010 - val_loss: 0.6035
# Epoch 7/10
#  - 18s - loss: 0.5970 - val_loss: 0.6074
# Epoch 8/10
#  - 18s - loss: 0.5922 - val_loss: 0.6035
# Epoch 9/10
#  - 18s - loss: 0.5882 - val_loss: 0.6039
# Epoch 10/10
#  - 17s - loss: 0.5837 - val_loss: 0.6089
# Train on 58519 samples, validate on 6503 samples
# Epoch 1/10
#  - 17s - loss: 0.7011 - val_loss: 0.6476
# Epoch 2/10
#  - 19s - loss: 0.6463 - val_loss: 0.6389
# Epoch 3/10
#  - 18s - loss: 0.6416 - val_loss: 0.6333
# Epoch 4/10
#  - 18s - loss: 0.6374 - val_loss: 0.6411
# Epoch 5/10
#  - 18s - loss: 0.6329 - val_loss: 0.6260
# Epoch 6/10
#  - 18s - loss: 0.6294 - val_loss: 0.6262
# Epoch 7/10
#  - 17s - loss: 0.6256 - val_loss: 0.6217
# Epoch 8/10
#  - 17s - loss: 0.6220 - val_loss: 0.6189
# Epoch 9/10
#  - 17s - loss: 0.6170 - val_loss: 0.6164
# Epoch 10/10
#  - 18s - loss: 0.6145 - val_loss: 0.6150
# Train on 58520 samples, validate on 6503 samples
# Epoch 1/10
#  - 17s - loss: 0.6973 - val_loss: 0.6444
# Epoch 2/10
#  - 18s - loss: 0.6426 - val_loss: 0.6404
# Epoch 3/10
#  - 18s - loss: 0.6348 - val_loss: 0.6366
# Epoch 4/10
#  - 18s - loss: 0.6295 - val_loss: 0.6323
# Epoch 5/10
#  - 18s - loss: 0.6260 - val_loss: 0.6281
# Epoch 6/10
#  - 18s - loss: 0.6229 - val_loss: 0.6267
# Epoch 7/10
#  - 19s - loss: 0.6204 - val_loss: 0.6311
# Epoch 8/10
#  - 19s - loss: 0.6173 - val_loss: 0.6270
# Epoch 9/10
#  - 21s - loss: 0.6141 - val_loss: 0.6178
# Epoch 10/10
#  - 20s - loss: 0.6094 - val_loss: 0.6192
#
# [0.69518923886710848, 0.7202489543983549, 0.72053827715821939]
# [86748.08120695199, 86124.1891796677, 86393.44773334476]

# %% [markdown]
# # Отладка

# %%
_train, _test = next(skf.split(pd_train.index, pd_train.label))
i_train = pd_train.iloc[_train]
i_test = pd_train.iloc[_test]

# %%
i_train
# Out:
#             context_id                             context_2  \
# 32457   93647138840824                 все не так уж плохо .
# 32458   93647138840824                 все не так уж плохо .
# 32459   93683303278579                              хорошо .
# 32460   93683303278579                              хорошо .
# 32461   93683303278579                              хорошо .
# 32462   93683303278579                              хорошо .
# 32463   93683303278579                              хорошо .
# 32464   93683303278579                              хорошо .
# 32465   93695962253917                     вперед . привет .
# 32466   93695962253917                     вперед . привет .
# 32469   93704925430634
# 32470   93704925430634
# 32471   93704925430634
# 32476   93725122701187
# 32480   93743846088060
# 32481   93743846088060
# 32482   93743846088060
# 32483   93743846088060
# 32489   93751930418528                                 нет .
# 32490   93751930418528                                 нет .
# 32491   93761033795797         не самая симпатичная защита .
# 32492   93761033795797         не самая симпатичная защита .
# 32493   93761033795797         не самая симпатичная защита .
# 32494   93761033795797         не самая симпатичная защита .
# 32495   93761033795797         не самая симпатичная защита .
# 32496   93761033795797         не самая симпатичная защита .
# 32497   93770923771356               если они двинутся . . .
# 32498   93770923771356               если они двинутся . . .
# 32499   93770923771356               если они двинутся . . .
# 32500   93770923771356               если они двинутся . . .
# ...                ...                                   ...
# 97503  281420667347488                  давай . ударь меня .
# 97504  281420667347488                  давай . ударь меня .
# 97505  281420667347488                  давай . ударь меня .
# 97506  281420667347488                  давай . ударь меня .
# 97507  281420667347488                  давай . ударь меня .
# 97508  281420667347488                  давай . ударь меня .
# 97509  281421690458811                 будь здоров , робби .
# 97510  281421690458811                 будь здоров , робби .
# 97511  281421690458811                 будь здоров , робби .
# 97512  281421690458811                 будь здоров , робби .
# 97513  281421690458811                 будь здоров , робби .
# 97514  281421690458811                 будь здоров , робби .
# 97515  281428817239034         ладно , возвращаемся в лифт .
# 97516  281428817239034         ладно , возвращаемся в лифт .
# 97517  281428817239034         ладно , возвращаемся в лифт .
# 97518  281428817239034         ладно , возвращаемся в лифт .
# 97519  281428817239034         ладно , возвращаемся в лифт .
# 97520  281428817239034         ладно , возвращаемся в лифт .
# 97521  281442741987260                                  эй !
# 97522  281442741987260                                  эй !
# 97523  281442741987260                                  эй !
# 97524  281442741987260                                  эй !
# 97525  281442741987260                                  эй !
# 97526  281442741987260                                  эй !
# 97527  281445178379747  прекрасное решение , мисс бланшард .
# 97528  281445178379747  прекрасное решение , мисс бланшард .
# 97529  281445178379747  прекрасное решение , мисс бланшард .
# 97530  281445178379747  прекрасное решение , мисс бланшард .
# 97531  281445178379747  прекрасное решение , мисс бланшард .
# 97532  281445178379747  прекрасное решение , мисс бланшард .
#
#                                                context_1  \
# 32457                          сделайте себя полезными .
# 32458                          сделайте себя полезными .
# 32459                              может будет подмога .
# 32460                              может будет подмога .
# 32461                              может будет подмога .
# 32462                              может будет подмога .
# 32463                              может будет подмога .
# 32464                              может будет подмога .
# 32465  у нас квест и первое задание , повесить его по...
# 32466  у нас квест и первое задание , повесить его по...
# 32469
# 32470
# 32471
# 32476
# 32480  а ты не замечаешь , потому что угол зрения не ...
# 32481  а ты не замечаешь , потому что угол зрения не ...
# 32482  а ты не замечаешь , потому что угол зрения не ...
# 32483  а ты не замечаешь , потому что угол зрения не ...
# 32489                                              вши .
# 32490                                              вши .
# 32491  когда кэтрин вернулась домой , она обнаружила ...
# 32492  когда кэтрин вернулась домой , она обнаружила ...
# 32493  когда кэтрин вернулась домой , она обнаружила ...
# 32494  когда кэтрин вернулась домой , она обнаружила ...
# 32495  когда кэтрин вернулась домой , она обнаружила ...
# 32496  когда кэтрин вернулась домой , она обнаружила ...
# 32497                                           выходи !
# 32498                                           выходи !
# 32499                                           выходи !
# 32500                                           выходи !
# ...                                                  ...
# 97503  ударь . я не боюсь , потому что я борюсь за сп...
# 97504  ударь . я не боюсь , потому что я борюсь за сп...
# 97505  ударь . я не боюсь , потому что я борюсь за сп...
# 97506  ударь . я не боюсь , потому что я борюсь за сп...
# 97507  ударь . я не боюсь , потому что я борюсь за сп...
# 97508  ударь . я не боюсь , потому что я борюсь за сп...
# 97509                     <CENSORED> . . . вою , гарри .
# 97510                     <CENSORED> . . . вою , гарри .
# 97511                     <CENSORED> . . . вою , гарри .
# 97512                     <CENSORED> . . . вою , гарри .
# 97513                     <CENSORED> . . . вою , гарри .
# 97514                     <CENSORED> . . . вою , гарри .
# 97515                                   какого дьявола ?
# 97516                                   какого дьявола ?
# 97517                                   какого дьявола ?
# 97518                                   какого дьявола ?
# 97519                                   какого дьявола ?
# 97520                                   какого дьявола ?
# 97521                                     давай оттуда !
# 97522                                     давай оттуда !
# 97523                                     давай оттуда !
# 97524                                     давай оттуда !
# 97525                                     давай оттуда !
# 97526                                     давай оттуда !
# 97527                               меня зовут спенсер .
# 97528                               меня зовут спенсер .
# 97529                               меня зовут спенсер .
# 97530                               меня зовут спенсер .
# 97531                               меня зовут спенсер .
# 97532                               меня зовут спенсер .
#
#                                                context_0 reply_id  \
# 32457                                    и это вытянем .        1
# 32458                                    и это вытянем .        2
# 32459                                     капитан лэнс ?        0
# 32460                                     капитан лэнс ?        1
# 32461                                     капитан лэнс ?        2
# 32462                                     капитан лэнс ?        3
# 32463                                     капитан лэнс ?        4
# 32464                                     капитан лэнс ?        5
# 32465                         а кто он , я его не знаю .        0
# 32466                         а кто он , я его не знаю .        1
# 32469                         он выглядит расстроенным .        2
# 32470                         он выглядит расстроенным .        3
# 32471                         он выглядит расстроенным .        4
# 32476  однако у меня не было жёлтой глазури , поэтому...        3
# 32480                             ты женился бы на ней ?        1
# 32481                             ты женился бы на ней ?        2
# 32482                             ты женился бы на ней ?        3
# 32483                             ты женился бы на ней ?        4
# 32489                                      так что . . .        4
# 32490                                      так что . . .        5
# 32491               она поспорила с тобой в том гараже .        0
# 32492               она поспорила с тобой в том гараже .        1
# 32493               она поспорила с тобой в том гараже .        2
# 32494               она поспорила с тобой в том гараже .        3
# 32495               она поспорила с тобой в том гараже .        4
# 32496               она поспорила с тобой в том гараже .        5
# 32497  выходи с поднятыми вверх руками , чтобы я мог ...        0
# 32498  выходи с поднятыми вверх руками , чтобы я мог ...        1
# 32499  выходи с поднятыми вверх руками , чтобы я мог ...        2
# 32500  выходи с поднятыми вверх руками , чтобы я мог ...        3
# ...                                                  ...      ...
# 97503   и не надо недооценивать силу обычного человека .        0
# 97504   и не надо недооценивать силу обычного человека .        1
# 97505   и не надо недооценивать силу обычного человека .        2
# 97506   и не надо недооценивать силу обычного человека .        3
# 97507   и не надо недооценивать силу обычного человека .        4
# 97508   и не надо недооценивать силу обычного человека .        5
# 97509                                не вкусно - то чё !        0
# 97510                                не вкусно - то чё !        1
# 97511                                не вкусно - то чё !        2
# 97512                                не вкусно - то чё !        3
# 97513                                не вкусно - то чё !        4
# 97514                                не вкусно - то чё !        5
# 97515                             вы вызвали меня сюда .        0
# 97516                             вы вызвали меня сюда .        1
# 97517                             вы вызвали меня сюда .        2
# 97518                             вы вызвали меня сюда .        3
# 97519                             вы вызвали меня сюда .        4
# 97520                             вы вызвали меня сюда .        5
# 97521                                           ты там ?        0
# 97522                                           ты там ?        1
# 97523                                           ты там ?        2
# 97524                                           ты там ?        3
# 97525                                           ты там ?        4
# 97526                                           ты там ?        5
# 97527                              я окружной прокурор .        0
# 97528                              я окружной прокурор .        1
# 97529                              я окружной прокурор .        2
# 97530                              я окружной прокурор .        3
# 97531                              я окружной прокурор .        4
# 97532                              я окружной прокурор .        5
#
#                                                    reply  label    confidence
# 32457                                     будет трудно .      2   0.909092886
# 32458   высоко поднять мы не сможем , так что не медли .      2  0.8059265579
# 32459                                 да , мисс гибсон .      2  0.9899184337
# 32460                          отставной капитан флота .      2  0.8011402464
# 32461                                    капитан риггз .      2  0.8468712695
# 32462                                    капитан башир .      2  0.9221820127
# 32463                           нет , капитан дженкинс .      2  0.9927068992
# 32464                                    капитан даффи .      2  0.9389570234
# 32465                        я не знаю , как его зовут .      2  0.9389397554
# 32466                       царь иудеи , некто христос .      2  0.7832186689
# 32469                                            как я .      2  0.9886788061
# 32470                     ага , потому что его поймали .      2   0.946953439
# 32471                            нет , он всегда такой .      2  0.9841277815
# 32476  можно есть в чистом виде , но ещё вкусно , есл...      2  0.6918374583
# 32480  нет . мне еще не встретилась та , на которой я...      2  0.8081732703
# 32481                                     в свое время .      2  0.9500355735
# 32482                                 нет , не женился .      2  0.9352485385
# 32483                                  на ком , на эми ?      2  0.9384237296
# 32489                                              вши .      0  0.9782632677
# 32490                                             фото .      0   0.995941353
# 32491             ты всегда выигрываешь , так нечестно .      0  0.9090854838
# 32492                                            кража ?      0  0.7534366152
# 32493                     что ж , ты бы проиграла спор .      0  0.9769014239
# 32494         в противостоянии со мной , ты проиграешь .      0  0.7671522479
# 32495               она поспорила с тобой в том гараже .      0  0.9741761456
# 32496                                     она не лгала .      0  0.8876853951
# 32497               выходи из машины ! выйти из машины .      0  0.8536467464
# 32498                                         шевелись !      0  0.5990934039
# 32499                                    стой на месте !      0  0.9066149025
# 32500                               держи руки на виду !      0  0.7980874957
# ...                                                  ...    ...           ...
# 97503            тогда мне стоит начать его отстаивать .      2  0.8177480577
# 97504                          я не человек и не зверь .      0   0.982558959
# 97505  если ты не станешь сражаться . . . то погибнешь .      2  0.9466146087
# 97506                       не надо недооценивать себя .      0  0.5914541934
# 97507      самое ужасное , что ты видишь во мне жертву .      2  0.8248682797
# 97508         всё зависит от того , на что ты способен .      2  0.5223173089
# 97509                                не вкусно - то чё !      0  0.9898211366
# 97510                       ну , он не очень съедобный .      2  0.8946027327
# 97511                 он собирается убить тебя , скотт .      0  0.9854364806
# 97512                                           лежать !      0  0.9639294831
# 97513                                 он очень горячий .      0  0.9696768905
# 97514                       ты не должна была это есть !      2  0.8224165493
# 97515                                         это ложь .      2  0.7437129349
# 97516  наоборот , я допрашиваю вас , но предпочел бы ...      2  0.8312257505
# 97517                                     я сам пришёл .      0  0.8082072661
# 97518                                 я отнес вас сюда .      2  0.7399971459
# 97519                          ваша дочь впустила меня .      0  0.7993667906
# 97520                           вы пришли в мое здание .      2   0.572088394
# 97521                                   да , я уже там .      2  0.9713862913
# 97522                               а где мне еще быть ?      2  0.8268257481
# 97523                                 нет , я уже дома .      2  0.9805532636
# 97524                         да , только что подъехал .      2  0.9407146841
# 97525                                               да .      1  0.8511226209
# 97526                                   ты ведь не там ?      0  0.9002489395
# 97527                            заместитель прокурора .      2  0.9639109045
# 97528  мистер томпсон , вы арестованы за фальсификаци...      0  0.5878749858
# 97529                              я окружной прокурор .      0  0.9425422003
# 97530                                          куратор .      0  0.8375521484
# 97531                                         прокурор .      0  0.8587523267
# 97532          детектив огилви , приятно познакомиться .      2  0.9480976331
#
# [65021 rows x 8 columns]

# %%
X_train = to_features_w2v(i_train)
X_test = to_features_w2v(i_test)
Y_train = trg_label_confidence(i_train)
Y_test = trg_label_confidence(i_test)

# %%
model.fit(X_train, Y_train, epochs=10, batch_size=256, verbose=2, validation_split=0.2)
# Out:
# Train on 52016 samples, validate on 13005 samples
# Epoch 1/10
#  - 16s - loss: 0.5819 - val_loss: 0.6090
# Epoch 2/10
#  - 16s - loss: 0.5776 - val_loss: 0.6067
# Epoch 3/10
#  - 16s - loss: 0.5743 - val_loss: 0.6061
# Epoch 4/10
#  - 16s - loss: 0.5680 - val_loss: 0.6102
# Epoch 5/10
#  - 16s - loss: 0.5661 - val_loss: 0.6084
# Epoch 6/10
#  - 16s - loss: 0.5601 - val_loss: 0.6073
# Epoch 7/10
#  - 16s - loss: 0.5571 - val_loss: 0.6085
# Epoch 8/10
#  - 17s - loss: 0.5527 - val_loss: 0.6110
# Epoch 9/10
#  - 17s - loss: 0.5476 - val_loss: 0.6043
# Epoch 10/10
#  - 16s - loss: 0.5434 - val_loss: 0.6089

# %%
Y_predict = model.predict(X_test)

# %%
print(mean_absolute_error(Y_test, Y_predict))
print(calc_ndcg_score(i_test, Y_predict))
# Out:
# 0.69282322577
# 86568.10480536966

# %%
model.load_weights("model_nn.w")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-4dac03210a72> in <module>()
# ----> 1 model.sample_weights()
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # Submit

# %%
def do_submit(submission_name, model_reg, to_features, to_target, model_fit_params=None):
    i_train = pd_train
    i_test = pd_public.copy()

    X_train = to_features(i_train)
    X_test = to_features(i_test)
    Y_train = to_target(i_train)

    model_reg.fit(X_train, Y_train, **model_fit_params)
    Y_predict = model_reg.predict(X_test)

    i_test["predict"] = Y_predict
    i_test.sort_values(["context_id", "predict"], ascending=[True, False], inplace=True)

    i_test[["context_id", "reply_id"]].to_csv(submission_name, index=False, header=False, sep="\t")
    
    return i_test

# %%
do_submit("w2v_nn_mlp.tsv", model, to_features_w2v, trg_label_confidence,
          {"epochs": 10, "batch_size": 256, "verbose": 2, "validation_split": 0.1}).head(15)
# Out:
# Train on 87779 samples, validate on 9754 samples
# Epoch 1/10
#  - 28s - loss: 0.6091 - val_loss: 0.6085
# Epoch 2/10
#  - 26s - loss: 0.6053 - val_loss: 0.6071
# Epoch 3/10
#  - 26s - loss: 0.6017 - val_loss: 0.6035
# Epoch 4/10
#  - 26s - loss: 0.5986 - val_loss: 0.6038
# Epoch 5/10
#  - 26s - loss: 0.5942 - val_loss: 0.6013
# Epoch 6/10
#  - 27s - loss: 0.5901 - val_loss: 0.6014
# Epoch 7/10
#  - 27s - loss: 0.5877 - val_loss: 0.5985
# Epoch 8/10
#  - 27s - loss: 0.5846 - val_loss: 0.5995
# Epoch 9/10
#  - 26s - loss: 0.5820 - val_loss: 0.5971
# Epoch 10/10
#  - 28s - loss: 0.5782 - val_loss: 0.6016
#            context_id     context_2                  context_1  \
# 3479  100097508986637
# 3478  100097508986637
# 3476  100097508986637
# 3475  100097508986637
# 3480  100097508986637
# 3477  100097508986637
# 3486  100149747456986                 как вы здесь оказались ?
# 3484  100149747456986                 как вы здесь оказались ?
# 3483  100149747456986                 как вы здесь оказались ?
# 3481  100149747456986                 как вы здесь оказались ?
# 3482  100149747456986                 как вы здесь оказались ?
# 3485  100149747456986                 как вы здесь оказались ?
# 3492  100441828256276  я чувствую !  по этой причине я здесь .
# 3487  100441828256276  я чувствую !  по этой причине я здесь .
# 3489  100441828256276  я чувствую !  по этой причине я здесь .
#
#                   context_0 reply_id  \
# 3479            выключай их        4
# 3478            выключай их        3
# 3476            выключай их        1
# 3475            выключай их        0
# 3480            выключай их        5
# 3477            выключай их        2
# 3486  не надо меня тянуть !        5
# 3484  не надо меня тянуть !        3
# 3483  не надо меня тянуть !        2
# 3481  не надо меня тянуть !        0
# 3482  не надо меня тянуть !        1
# 3485  не надо меня тянуть !        4
# 3492    мой духовный путь !        5
# 3487    мой духовный путь !        0
# 3489    мой духовный путь !        2
#
#                                                  reply   predict
# 3479                                   пытаюсь , сэр .  0.640513
# 3478                                       я пытаюсь !  0.464230
# 3476             ты не выключишь , тогда € сам выключу  0.265819
# 3475                                   выключить что ?  0.057735
# 3480                                         выключите -0.237809
# 3477                                       выключить ? -0.328770
# 3486                  что " не надо " ? не надо меня .  0.478471
# 3484                                   мне уже легче .  0.422974
# 3483                    я не могу позволить вам уйти .  0.385519
# 3481                                           ладно .  0.176011
# 3482                 мне показалось , вы меня зовете .  0.102278
# 3485                                        извините .  0.059266
# 3492                               уильям , довольно .  0.147485
# 3487                               нет никакого бога .  0.025259
# 3489  иным бог шепчет в уши . мне же он кричит в них !  0.020724
