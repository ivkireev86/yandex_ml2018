# %%
from zipfile import ZipFile
import pandas as pd
import numpy as np

# %% [markdown]
# # Загрузка данных

# %%
def gen_parcer(f):
    for line in f.readlines():
        yield line.decode().strip().split("\t")

# %%
with ZipFile('data.zip') as datazip:
    with datazip.open('train.tsv') as f:
        pd_train = pd.DataFrame(gen_parcer(f),
                                columns=["context_id", "context_2", "context_1", "context_0", "reply_id", "reply",
                                         "label", "confidence"])
    with datazip.open('public.tsv') as f:
         pd_public = pd.DataFrame(gen_parcer(f),
                                  columns=["context_id", "context_2", "context_1", "context_0", "reply_id", "reply"])

# %%
pd_train.head()
# Out:
#     context_id                                          context_2  \
# 0  22579918886  кликни на меня а потом на надпись " видео - зв...
# 1  22579918886  кликни на меня а потом на надпись " видео - зв...
# 2  22579918886  кликни на меня а потом на надпись " видео - зв...
# 3  22579918886  кликни на меня а потом на надпись " видео - зв...
# 4  22579918886  кликни на меня а потом на надпись " видео - зв...
#
#            context_1                context_0 reply_id  \
# 0  о , я тебя вижу .  ладно , повесь трубку .        0
# 1  о , я тебя вижу .  ладно , повесь трубку .        1
# 2  о , я тебя вижу .  ладно , повесь трубку .        2
# 3  о , я тебя вижу .  ладно , повесь трубку .        3
# 4  о , я тебя вижу .  ладно , повесь трубку .        4
#
#                       reply    label    confidence
# 0                 не могу .     good  0.8753516175
# 1    нет , звонить буду я .  neutral  0.9009682113
# 2  слушай , я не мог уйти .      bad  0.8843202145
# 3   я не прекращу звонить .     good  0.9825304673
# 4              я звоню им .     good  0.8380535096

# %%
pd_public.head()
# Out:
#      context_id                                          context_2 context_1  \
# 0  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 1  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 2  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 3  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
# 4  138920940977  знаешь , я иногда подумываю , что тебе надо пр...  не - а .
#
#   context_0 reply_id               reply
# 0     нет ?        0               неа .
# 1     нет ?        1     нет , не хочу .
# 2     нет ?        2               нет .
# 3     нет ?        3     конечно , нет .
# 4     нет ?        4  разумеется , нет .

# %%
pd_train.count()
# Out:
# context_id    97533
# context_2     97533
# context_1     97533
# context_0     97533
# reply_id      97533
# reply         97533
# label         97533
# confidence    97533
# dtype: int64

# %%
pd_public.count()
# Out:
# context_id    9968
# context_2     9968
# context_1     9968
# context_0     9968
# reply_id      9968
# reply         9968
# dtype: int64

# %%
target_encoder = {'bad': 0, 'good': 2, 'neutral': 1}  
pd_train.label = pd_train.label.map(target_encoder)

# %%
pd_train.confidence = pd_train.confidence.astype(float)

# %%
pd_data = pd.concat([pd_train, pd_public], axis=0).reset_index(drop=True)
pd_data.label.fillna(-1, inplace=True)
pd_data.confidence.fillna(0.0, inplace=True)

# %% [markdown]
# # Что за данные

# %%
pd_train.shape, pd_public.shape, pd_data.shape
# Out:
# ((97533, 8), (9968, 6), (107501, 8))

# %%
pd_data.groupby("label")["context_id"].count() / len(pd_data)
# Out:
# label
# -1.0    0.092725
#  0.0    0.323439
#  1.0    0.104687
#  2.0    0.479149
# Name: context_id, dtype: float64

# %% [markdown]
# # Простой бейзлайн

# %% [markdown]
# ## features

# %%
from scipy import sparse

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv_all = CountVectorizer()
s_words = pd_data[["context_2", "context_1", "context_0", "reply"]].apply(lambda x: " ".join(x), axis=1)
cv_all.fit(s_words)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
tfidf_all = TfidfVectorizer()

# %%
def fit_tfidf(**kwargs):
    global tfidf_all
    tfidf_all = TfidfVectorizer(**kwargs)
    s_words = pd_data[["context_2", "context_1", "context_0", "reply"]].apply(lambda x: " ".join(x), axis=1)
    tfidf_all.fit(s_words)

# %%
def to_features_cv(df):
    context = cv_all.transform(df[["context_2", "context_1", "context_0"]].apply(lambda x: " ".join(x), axis=1))
    reply = cv_all.transform(df["reply"])
    features = sparse.hstack([context, reply])
    return features

# %%
def to_features_tfidf(df):
    context = tfidf_all.transform(df[["context_2", "context_1", "context_0"]].apply(lambda x: " ".join(x), axis=1))
    reply = tfidf_all.transform(df["reply"])
    features = sparse.hstack([context, reply])
    return features

# %% [markdown]
# ## vectors

# %% [markdown]
# - rusvectores
# - nlpub (russion distribution t...)

# %% [markdown]
# ## crossval

# %%
from tqdm import tqdm_notebook

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=3)

# %%
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor

# %%
class RandomMinMaxRegressor(object):
    def __init__(self):
        self.min_y = None
        self.max_y = None
    
    def fit(self, x, y):
        self.min_y = y.min()
        self.max_y = y.max()
    
    def predict(self, x):
        return np.random.random(x.shape[0]) * (self.max_y - self.min_y) + self.min_y

# %%
from sklearn.metrics import mean_absolute_error

# %%
def calc_ndcg_score(df, y_predict):
    df = df.copy()
    df["predict"] = y_predict
    #dcg
    df.sort_values(["context_id", "predict"], ascending=[True, False], inplace=True)
    df["row_count"] = df.groupby("context_id").cumcount()+1
    df["dcg"] = df["label"] / np.log2(df["row_count"] + 1)
    #idcg
    df.sort_values(["context_id", "label"], ascending=[True, False], inplace=True)
    df["row_count"] = df.groupby("context_id").cumcount()+1
    df["idcg"] = df["label"] / np.log2(df["row_count"] + 1)
    
    df_context = df.groupby("context_id").sum()
    return (df_context["dcg"] / df_context["idcg"]).mean() * 100000

# %%
def do_cross_val(model_reg, p_sampling, to_features, to_target, sampling_params):
    mae_test = []
    mae_errors = []
    ndcg_scores = []

    for _train, _test in tqdm_notebook(skf.split(pd_train.index, pd_train.label), total=3):
        i_train = p_sampling(pd_train.iloc[_train], **sampling_params)
        i_test = pd_train.iloc[_test]

        X_train = to_features(i_train)
        X_test = to_features(i_test)
        Y_train = to_target(i_train)
        Y_test = to_target(i_test)

        model_reg.fit(X_train, Y_train)
        Y_predict = model_reg.predict(X_test)
        
        mae_test.append(mean_absolute_error(Y_train, model_reg.predict(X_train)))
        mae_errors.append(mean_absolute_error(Y_test, Y_predict))
        ndcg_scores.append(calc_ndcg_score(i_test, Y_predict))

    print(sorted(mae_test))
    print(sorted(mae_errors))
    print(sorted(ndcg_scores))

# %% [markdown]
# ## target

# %%
trg_label = lambda x: x.label.values

# %%
trg_label_confidence = lambda x: (x.label.values - 1) * x.confidence.values.astype(np.float)

# %% [markdown]
# ## Нормальные варианты

# %%
from sklearn.linear_model import Ridge

# %%
fit_tfidf(analyzer='char', ngram_range=(3,4))

# %%
do_cross_val(Ridge(alpha=20.0), m_sampling, to_features_tfidf, trg_label,
             {})
# Out:
# A Jupyter Widget
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tqdm\_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "C:\ProgramData\Anaconda3\lib\_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# [0.7707396527255045, 0.771191720398295, 0.7714803030187314]
# [0.8226197062858732, 0.8234261880833347, 0.8234458046155703]
# [86250.81379658228, 86463.30007075329, 86613.92412908383]

# %%
do_cross_val(Ridge(alpha=20.0), m_sampling, to_features_tfidf, trg_label,
             {})
# Out:
# A Jupyter Widget
# [0.9447154995288046, 0.9448030371268662, 0.9449557366445199]
# [0.8412207827569289, 0.8425614524114927, 0.8429086689676474]
# [85531.86049534313, 85576.6779517952, 85803.07900825172]

# %%
import lightgbm

# %%
do_cross_val(lightgbm.LGBMRegressor(), m_sampling, to_features_tfidf, trg_label,
             {})
# Out:
# A Jupyter Widget
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:447: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:447: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:447: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# [0.9473249493145631, 0.9478841272710248, 0.9479454209874395]
# [0.8400871509948474, 0.841501459212799, 0.8416204327962735]
# [85461.05223789712, 85468.76426682134, 85680.45174335346]

# %%
do_cross_val(Ridge(alpha=20.0), m_sampling, to_features_tfidf, trg_label,
             {"p_con0_mul": 1})
# Out:
# A Jupyter Widget
# [0.756170131256931, 0.7565562164899753, 0.7569632328059338]
# [0.819359380002962, 0.8196217519678458, 0.819749389971439]
# [86283.3338542383, 86401.44072599198, 86572.15282855151]

# %%
do_cross_val(Ridge(alpha=20.0), m_sampling, to_features_tfidf, trg_label,
             {"p_plus": 0.20})
# Out:
# A Jupyter Widget
# [0.7975784229318101, 0.7987264967410189, 0.79989051592151]
# [0.8363488366512923, 0.837426607204882, 0.8374353175381992]
# [86240.32439458236, 86252.92109078343, 86548.8202303653]

# %%
do_cross_val(Ridge(alpha=1.0), m_sampling, to_features_tfidf, trg_label,
             {"p_plus": .10, "p_con0_mul": 1})
# Out:
# A Jupyter Widget
# [0.6024565308531346, 0.6026688657792648, 0.6027879598479483]
# [0.8202469613339363, 0.8213296777318918, 0.8220450205647197]
# [85695.66577442182, 85706.08971794875, 85826.71108508714]

# %%
pd_os_good =pd.read_pickle("pd_os_good.pickle")
pd_os_bad = pd.read_pickle("pd_os_bad.pickle")

# %%
def m_sampling(df, remove=None, p_plus=None, p_con0_mul=None):
    size = len(df)
    
    if remove is not None:
        df = df.sort_values("confidence").iloc[int(size * remove):]
        
    if p_plus is not None:
        ix_context = np.random.choice(df.context_id.unique(), size=int(size * p_plus))
        df_app = pd_train[pd_train.context_id.isin(ix_context)]
        df_app = df_app[~df_app.duplicated(["context_id"], keep="first")].copy()
        df_app["reply"] = np.random.choice(df[df.label.eq(0)].reply, size=len(df_app))
        df_app["label"] = 0
        df_app["confidence"] = 0.7
        df = pd.concat([df, df_app]).reset_index(drop=True)
    
    if p_con0_mul is not None:
        df_app = df[~df.context_2.eq("")][["context_id", "context_2", "context_1"]]
        df_app = df_app[~df_app.duplicated(["context_id"], keep="first")].copy()
        df_app["context_id"] = 0
        df_app.rename(columns={"context_2": "context_0", "context_1": "reply"}, inplace=True)
        df_app["context_2"] = ""
        df_app["context_1"] = ""
        df_app["label"] = 2
        df_app["confidence"] = 0.7
        df = pd.concat([df, df_app]).reset_index(drop=True)
        
    df = pd.concat([df, pd_os_good, pd_os_bad]).reset_index(drop=True)
        
    return df.copy()

# %%
m_sampling(pd_train, p_plus=0.9, p_con0_mul=1)
# Out:
#         confidence                                          context_0  \
# 0         0.875352                            ладно , повесь трубку .
# 1         0.900968                            ладно , повесь трубку .
# 2         0.884320                            ладно , повесь трубку .
# 3         0.982530                            ладно , повесь трубку .
# 4         0.838054                            ладно , повесь трубку .
# 5         0.955718                            ладно , повесь трубку .
# 6         0.909115  я пытаюсь добраться до юджина , но , кажется ,...
# 7         0.984621  я пытаюсь добраться до юджина , но , кажется ,...
# 8         0.833307  я пытаюсь добраться до юджина , но , кажется ,...
# 9         0.800272  я пытаюсь добраться до юджина , но , кажется ,...
# 10        0.970601  я пытаюсь добраться до юджина , но , кажется ,...
# 11        0.974367  я пытаюсь добраться до юджина , но , кажется ,...
# 12        0.721837                           знаю только понаслышке .
# 13        0.917949                           знаю только понаслышке .
# 14        0.613157                           знаю только понаслышке .
# 15        0.956320                           знаю только понаслышке .
# 16        0.976917                           знаю только понаслышке .
# 17        0.835719                           знаю только понаслышке .
# 18        0.939344                                     да , хорошим .
# 19        0.507729                                     да , хорошим .
# 20        0.941863                                     да , хорошим .
# 21        0.667493                                     да , хорошим .
# 22        0.712409                                     да , хорошим .
# 23        0.815436                                     да , хорошим .
# 24        0.867679                       мне больше нравится второе .
# 25        0.653608                       мне больше нравится второе .
# 26        0.903552                       мне больше нравится второе .
# 27        0.944580                       мне больше нравится второе .
# 28        0.871350                       мне больше нравится второе .
# 29        0.969688                       мне больше нравится второе .
# ...            ...                                                ...
# 123155    0.700000                         нет , правда , я не могу .
# 123156    0.700000                    эй , девчонки , что тут у вас ?
# 123157    0.700000                                за что мне платят .
# 123158    0.700000                                   доктор пек . . .
# 123159    0.700000                                       поверь мне .
# 123160    0.700000  потому что , неважно насколько страшен сон , к...
# 123161    0.700000                а это моя напарница , флора хаким .
# 123162    0.700000  эй , ты можешь притворяться , что ненавидишь м...
# 123163    0.700000                       они отвезут нас в балтимор .
# 123164    0.700000                                      спасибо . . .
# 123165    0.700000                                      до свидания .
# 123166    0.700000                     ♪ как молоды и невинны мы были
# 123167    0.700000                                   всё образуется .
# 123168    0.700000                                       в чём дело ?
# 123169    0.700000                 ты что , совсем слетел с катушек ?
# 123170    0.700000                                           джемма .
# 123171    0.700000                                         проснись !
# 123172    0.700000            у тебя есть здесь другие родственники ?
# 123173    0.700000                                где генерал фромм ?
# 123174    0.700000                 я не хочу думать ни о ком из них .
# 123175    0.700000                                          в каире .
# 123176    0.700000                   так почему я должна беспокоиться
# 123177    0.700000                                  что сказал врач ?
# 123178    0.700000           что ты натворил ? не можешь удержаться ?
# 123179    0.700000                                               эй !
# 123180    0.700000                               давай . ударь меня .
# 123181    0.700000                              будь здоров , робби .
# 123182    0.700000                      ладно , возвращаемся в лифт .
# 123183    0.700000                                               эй !
# 123184    0.700000               прекрасное решение , мисс бланшард .
#
#                                                 context_1  \
# 0                                       о , я тебя вижу .
# 1                                       о , я тебя вижу .
# 2                                       о , я тебя вижу .
# 3                                       о , я тебя вижу .
# 4                                       о , я тебя вижу .
# 5                                       о , я тебя вижу .
# 6        слушайте , мы с женой . . . совсем заблудились .
# 7        слушайте , мы с женой . . . совсем заблудились .
# 8        слушайте , мы с женой . . . совсем заблудились .
# 9        слушайте , мы с женой . . . совсем заблудились .
# 10       слушайте , мы с женой . . . совсем заблудились .
# 11       слушайте , мы с женой . . . совсем заблудились .
# 12                       кажется , я там ни разу не был .
# 13                       кажется , я там ни разу не был .
# 14                       кажется , я там ни разу не был .
# 15                       кажется , я там ни разу не был .
# 16                       кажется , я там ни разу не был .
# 17                       кажется , я там ни разу не был .
# 18                         он был хорошим псом , линдси ?
# 19                         он был хорошим псом , линдси ?
# 20                         он был хорошим псом , линдси ?
# 21                         он был хорошим псом , линдси ?
# 22                         он был хорошим псом , линдси ?
# 23                         он был хорошим псом , линдси ?
# 24      я предпочитаю ни то , ни другое , но мой напар...
# 25      я предпочитаю ни то , ни другое , но мой напар...
# 26      я предпочитаю ни то , ни другое , но мой напар...
# 27      я предпочитаю ни то , ни другое , но мой напар...
# 28      я предпочитаю ни то , ни другое , но мой напар...
# 29      я предпочитаю ни то , ни другое , но мой напар...
# ...                                                   ...
# 123155
# 123156
# 123157
# 123158
# 123159
# 123160
# 123161
# 123162
# 123163
# 123164
# 123165
# 123166
# 123167
# 123168
# 123169
# 123170
# 123171
# 123172
# 123173
# 123174
# 123175
# 123176
# 123177
# 123178
# 123179
# 123180
# 123181
# 123182
# 123183
# 123184
#
#                                                 context_2    context_id  \
# 0       кликни на меня а потом на надпись " видео - зв...   22579918886
# 1       кликни на меня а потом на надпись " видео - зв...   22579918886
# 2       кликни на меня а потом на надпись " видео - зв...   22579918886
# 3       кликни на меня а потом на надпись " видео - зв...   22579918886
# 4       кликни на меня а потом на надпись " видео - зв...   22579918886
# 5       кликни на меня а потом на надпись " видео - зв...   22579918886
# 6                                      бывало и получше .   50117448291
# 7                                      бывало и получше .   50117448291
# 8                                      бывало и получше .   50117448291
# 9                                      бывало и получше .   50117448291
# 10                                     бывало и получше .   50117448291
# 11                                     бывало и получше .   50117448291
# 12                                     ну , это не ново .   72855813972
# 13                                     ну , это не ново .   72855813972
# 14                                     ну , это не ново .   72855813972
# 15                                     ну , это не ново .   72855813972
# 16                                     ну , это не ново .   72855813972
# 17                                     ну , это не ново .   72855813972
# 18                                                  ага .   76323501777
# 19                                                  ага .   76323501777
# 20                                                  ага .   76323501777
# 21                                                  ага .   76323501777
# 22                                                  ага .   76323501777
# 23                                                  ага .   76323501777
# 24      как вы предпочитаете " похищенные " или " подо...  127768564286
# 25      как вы предпочитаете " похищенные " или " подо...  127768564286
# 26      как вы предпочитаете " похищенные " или " подо...  127768564286
# 27      как вы предпочитаете " похищенные " или " подо...  127768564286
# 28      как вы предпочитаете " похищенные " или " подо...  127768564286
# 29      как вы предпочитаете " похищенные " или " подо...  127768564286
# ...                                                   ...           ...
# 123155                                                                0
# 123156                                                                0
# 123157                                                                0
# 123158                                                                0
# 123159                                                                0
# 123160                                                                0
# 123161                                                                0
# 123162                                                                0
# 123163                                                                0
# 123164                                                                0
# 123165                                                                0
# 123166                                                                0
# 123167                                                                0
# 123168                                                                0
# 123169                                                                0
# 123170                                                                0
# 123171                                                                0
# 123172                                                                0
# 123173                                                                0
# 123174                                                                0
# 123175                                                                0
# 123176                                                                0
# 123177                                                                0
# 123178                                                                0
# 123179                                                                0
# 123180                                                                0
# 123181                                                                0
# 123182                                                                0
# 123183                                                                0
# 123184                                                                0
#
#         label                                              reply reply_id
# 0           2                                          не могу .        0
# 1           1                             нет , звонить буду я .        1
# 2           0                           слушай , я не мог уйти .        2
# 3           2                            я не прекращу звонить .        3
# 4           2                                       я звоню им .        4
# 5           0                             просто повесь трубку .        5
# 6           0                                            едете ?        0
# 7           0                                             едем .        1
# 8           2                         куда же вы едете , месье ?        2
# 9           2                      берите бутылку , а мы такси .        3
# 10          2  господи , куда же это вы решили отправиться пе...        4
# 11          0                                             куда ?        5
# 12          2                                    зато я слышал .        0
# 13          2                 я слышал , там многое изменилось .        1
# 14          0                              но видел фотографии .        2
# 15          2                          оттуда видно всю долину .        3
# 16          0                             я там пел на террасе .        4
# 17          2                            а я слышал , и не раз .        5
# 18          0                                          хороший .        0
# 19          0                                     он разбил её .        1
# 20          2                       ему было хреново , дорогая .        2
# 21          2  помнишь , как у него фокусы никогда не получал...        3
# 22          0       джимми думал , что ему удастся выкрутиться .        4
# 23          0                             клара , мне так жаль .        5
# 24          2                   вы мне тоже нравитесь , доктор .        0
# 25          1                                         мне тоже .        1
# 26          2                       а я предпочитаю " лайнел " .        2
# 27          0                         но мне тоже это нравится .        3
# 28          2                            забавно , но мне тоже .        4
# 29          2                            я выбираю достоинство .        5
# ...       ...                                                ...      ...
# 123155      2                                         пойдемте .      NaN
# 123156      2                     это что , магазин какой - то ?      NaN
# 123157      2                       я не спала с этими парнями .      NaN
# 123158      2                      ваша болезнь наследственная .      NaN
# 123159      2                                         как дела ?      NaN
# 123160      2                                     уже недалеко !      NaN
# 123161      2      и наконец . . . самая известная певица египта      NaN
# 123162      2  я получил десятки текстов , которые говорят об...      NaN
# 123163      2                                можешь взять вещи ?      NaN
# 123164      2                                  нет , нет , нет .      NaN
# 123165      2                     энид , можно тебя на минутку ?      NaN
# 123166      2                  ♪ она , возможно , не помнит меня      NaN
# 123167      2                                       как обычно .      NaN
# 123168      2                       сколько с тебя взял хромой ?      NaN
# 123169      2  а сколько , по - твоему , я должен был потрати...      NaN
# 123170      2                                       я его дочь .      NaN
# 123171      2                                       просыпайся .      NaN
# 123172      2               я имею ввиду , с кем ты останешься ?      NaN
# 123173      2  он отстранен . я - новый командующий армии . б...      NaN
# 123174      2                                            о них ?      NaN
# 123175      2                                 он требует выкуп ?      NaN
# 123176      2                       она была уже мертва для меня      NaN
# 123177      2                              врача у неё не было .      NaN
# 123178      2     ничего я не сделал . ты что , на его стороне ?      NaN
# 123179      2                                  где ты это взял ?      NaN
# 123180      2  ударь . я не боюсь , потому что я борюсь за сп...      NaN
# 123181      2                     <CENSORED> . . . вою , гарри .      NaN
# 123182      2                                   какого дьявола ?      NaN
# 123183      2                                     давай оттуда !      NaN
# 123184      2                               меня зовут спенсер .      NaN
#
# [123185 rows x 8 columns]

# %%
df = pd_train

# %%
df_app = df[~df.context_2.eq("")][["context_id", "context_2", "context_1"]]
df_app = df_app[~df_app.duplicated(["context_id"], keep="first")].copy()

# %%
df.head()
# Out:
#     context_id                                          context_2  \
# 0  22579918886  кликни на меня а потом на надпись " видео - зв...
# 1  22579918886  кликни на меня а потом на надпись " видео - зв...
# 2  22579918886  кликни на меня а потом на надпись " видео - зв...
# 3  22579918886  кликни на меня а потом на надпись " видео - зв...
# 4  22579918886  кликни на меня а потом на надпись " видео - зв...
#
#            context_1                context_0 reply_id  \
# 0  о , я тебя вижу .  ладно , повесь трубку .        0
# 1  о , я тебя вижу .  ладно , повесь трубку .        1
# 2  о , я тебя вижу .  ладно , повесь трубку .        2
# 3  о , я тебя вижу .  ладно , повесь трубку .        3
# 4  о , я тебя вижу .  ладно , повесь трубку .        4
#
#                       reply  label  confidence
# 0                 не могу .      2    0.875352
# 1    нет , звонить буду я .      1    0.900968
# 2  слушай , я не мог уйти .      0    0.884320
# 3   я не прекращу звонить .      2    0.982530
# 4              я звоню им .      2    0.838054

# %%
df_app["context_id"] = 0
df_app.rename(columns={"context_2": "context_0", "context_1": "reply"}, inplace=True)
df_app["context_2"] = ""
df_app["context_1"] = ""
df_app["label"] = 2
df_app["confidence"] = 0.7
# Out:
#             context_id                                          context_2  \
# 0          22579918886  кликни на меня а потом на надпись " видео - зв...
# 6          50117448291                                 бывало и получше .
# 12         72855813972                                 ну , это не ново .
# 18         76323501777                                              ага .
# 24        127768564286  как вы предпочитаете " похищенные " или " подо...
# 30        135053376199                как я уже говорил , тут 4 спальни .
# 31        213012655515   не хочу иметь дела с негативными последствиями .
# 37        243724867653                                       ответь мне .
# 43        275211951503      и вы стоите миллионы долларов городу ущерба .
# 55        297851249865                              я позвоню федералам .
# 73        326317350389        джэми , я не могу быть тебе просто другом .
# 79        352135203400                                          сэмюэль .
# 85        428406076389  ты просто . . . продолжай цепляться за свое , ...
# 97        456958955733                       о , а я не смогу , или что ?
# 103       457030053322                                                и ?
# 109       465148858400                                                  !
# 127       547001896994  вы уверены , что хотите купить машину , но поч...
# 133       548670776224            думаю , кодекс был истинным соблазном .
# 145       555494867639                                        я направо .
# 157       558395869976                                          это . . .
# 163       568861803063                                      с каких пор ?
# 169       581610319485                                иди , как красиво .
# 181       611593846799                                   ты спал с ники ?
# 189       614230256995                                             гэри ?
# 208       643528390848                               мой пиджак еще там .
# 214       653200183145                              прошу вас , офицеры !
# 232       674350458110                             я тут был неподалеку .
# 238       684155190903  по всей видимости им нужен был велосипедист ту...
# 239       706512049727                                   окей , бродяга .
# 251       759475764687  а под конец , малыш , ты исполнишь и мой после...
# ...                ...                                                ...
# 97199  280398321868810                         нет , правда , я не могу .
# 97205  280401032403253                    эй , девчонки , что тут у вас ?
# 97229  280417368922799                                за что мне платят .
# 97242  280457007969709                                   доктор пек . . .
# 97244  280477278255373                                       поверь мне .
# 97250  280483698911803  потому что , неважно насколько страшен сон , к...
# 97258  280516762218748                а это моя напарница , флора хаким .
# 97270  280551172933698  эй , ты можешь притворяться , что ненавидишь м...
# 97282  280615634562478                       они отвезут нас в балтимор .
# 97288  280619635687370                                      спасибо . . .
# 97294  280634055483268                                      до свидания .
# 97312  280687047093146                     ♪ как молоды и невинны мы были
# 97326  280781798425128                                   всё образуется .
# 97338  280913170806207                                       в чём дело ?
# 97346  280923481281580                 ты что , совсем слетел с катушек ?
# 97352  280968567344151                                           джемма .
# 97365  281039842085948                                         проснись !
# 97371  281056091681197            у тебя есть здесь другие родственники ?
# 97377  281113122967707                                где генерал фромм ?
# 97407  281189550030392                 я не хочу думать ни о ком из них .
# 97419  281238365710633                                          в каире .
# 97431  281257575503930                   так почему я должна беспокоиться
# 97443  281315804039325                                  что сказал врач ?
# 97449  281318971366070           что ты натворил ? не можешь удержаться ?
# 97473  281350282785471                                               эй !
# 97503  281420667347488                               давай . ударь меня .
# 97509  281421690458811                              будь здоров , робби .
# 97515  281428817239034                      ладно , возвращаемся в лифт .
# 97521  281442741987260                                               эй !
# 97527  281445178379747               прекрасное решение , мисс бланшард .
#
#                                                context_1
# 0                                      о , я тебя вижу .
# 6       слушайте , мы с женой . . . совсем заблудились .
# 12                      кажется , я там ни разу не был .
# 18                        он был хорошим псом , линдси ?
# 24     я предпочитаю ни то , ни другое , но мой напар...
# 30                          я понимаю , вы это ожидали .
# 31     надеюсь вы больше не собираетесь сегодня меня ...
# 37                                                оуэн .
# 43                         я всегда хотела сделать это .
# 55                           они тебе ничего не скажут .
# 73              я думала , что увидела в тебе что - то .
# 79                                     епископ сэнфорд .
# 85                                   ты жалкий слизняк .
# 97     я просто говорю , что я против аборта , только...
# 103                                      вы арестованы .
# 109    ты единственный свидетель , и убийцы не знают ...
# 127                                    почему не синюю ?
# 133      у нас всё готово к публикации , какая жалость .
# 145                                          ты налево .
# 157                                             птичка .
# 163            как стал лейтенантом . мои поздравления .
# 169                                     он антикварный ?
# 181                        нет , ники не по этой части .
# 189                                   посмотрите здесь .
# 208                                         оставь его .
# 214                   нет необходимости применять силу !
# 232                                   зашел повидаться .
# 238                               я убью своего агента .
# 239                                             хорошо .
# 251          исполню . что ты прикажешь мне напоследок ?
# ...                                                  ...
# 97199                                         пойдемте .
# 97205                     это что , магазин какой - то ?
# 97229                       я не спала с этими парнями .
# 97242                      ваша болезнь наследственная .
# 97244                                         как дела ?
# 97250                                     уже недалеко !
# 97258      и наконец . . . самая известная певица египта
# 97270  я получил десятки текстов , которые говорят об...
# 97282                                можешь взять вещи ?
# 97288                                  нет , нет , нет .
# 97294                     энид , можно тебя на минутку ?
# 97312                  ♪ она , возможно , не помнит меня
# 97326                                       как обычно .
# 97338                       сколько с тебя взял хромой ?
# 97346  а сколько , по - твоему , я должен был потрати...
# 97352                                       я его дочь .
# 97365                                       просыпайся .
# 97371               я имею ввиду , с кем ты останешься ?
# 97377  он отстранен . я - новый командующий армии . б...
# 97407                                            о них ?
# 97419                                 он требует выкуп ?
# 97431                       она была уже мертва для меня
# 97443                              врача у неё не было .
# 97449     ничего я не сделал . ты что , на его стороне ?
# 97473                                  где ты это взял ?
# 97503  ударь . я не боюсь , потому что я борюсь за сп...
# 97509                     <CENSORED> . . . вою , гарри .
# 97515                                   какого дьявола ?
# 97521                                     давай оттуда !
# 97527                               меня зовут спенсер .
#
# [8580 rows x 3 columns]

# %% [markdown]
# ## Неудачные варианты

# %%
fit_tfidf(max_features=10000)
do_cross_val(Lasso(alpha=0.01), to_features_tfidf, trg_label_confidence)
# Out:
# A Jupyter Widget
# [0.75838986817906762, 0.75749894796205131, 0.75695730065427458]
# [82749.59984256358, 82818.22569952125, 82951.3881202625]

# %%
from sklearn.linear_model import ElasticNet
fit_tfidf(max_features=10000)
do_cross_val(ElasticNet(alpha=1.0), to_features_tfidf, trg_label_confidence)
# Out:
# A Jupyter Widget
# [0.75838986817906762, 0.75749894796205131, 0.75695730065427458]
# [82749.59984256358, 82818.22569952125, 82951.3881202625]

# %%
fit_tfidf(max_features=20000)
do_cross_val(LinearRegression(), to_features_tfidf)
# Out:
# A Jupyter Widget
# [1.1641773562812208, 1.2216055918557263, 1.2445674321405]
# [85160.73563781707, 85201.6761086984, 85174.57705347847]

# %%
fit_tfidf(max_features=5000)
do_cross_val(LinearRegression(), to_features_tfidf)
# Out:
# A Jupyter Widget
# [1.1641773562812208, 1.2216055918557263, 1.2445674321405]
# [85160.73563781707, 85201.6761086984, 85174.57705347847]

# %%
fit_tfidf(max_features=1000)
do_cross_val(LinearRegression(), to_features_tfidf)
# Out:
# A Jupyter Widget
# [1.1641773562812208, 1.2216055918557263, 1.2445674321405]
# [85160.73563781707, 85201.6761086984, 85174.57705347847]

# %%
fit_tfidf(max_features=200)
do_cross_val(LinearRegression(), to_features_tfidf)
# Out:
# A Jupyter Widget
# [1.1641773562812208, 1.2216055918557263, 1.2445674321405]
# [85160.73563781707, 85201.6761086984, 85174.57705347847]

# %%
do_cross_val(RandomMinMaxRegressor())
# Out:
# A Jupyter Widget
# [0.94215100562127641, 0.94450351137377053, 0.94044066978111984]
# [82635.87988159526, 82487.80155424896, 82826.7969582632]

# %%
def do_worst_ndcg():
    mae_errors = []
    ndcg_scores = []

    for _train, _test in tqdm_notebook(skf.split(pd_train.index, pd_train.label), total=3):
        i_test = pd_train.iloc[_test].copy().sort_values(["context_id", "label"], ascending=[True, False])
        
        Y_test = i_test.sort_values(["context_id", "label"], ascending=[True, False]).label.values
        Y_predict = i_test.sort_values(["context_id", "label"], ascending=[True, True]).label.values
        
        mae_errors.append(mean_absolute_error(Y_test, Y_predict))
        ndcg_scores.append(calc_ndcg_score(i_test, Y_predict))

    print(mae_errors)
    print(ndcg_scores)
do_worst_ndcg()
# Out:
# A Jupyter Widget
# [1.1195250984251968, 1.1126695579957553, 1.1291294986158105]
# [77475.71260547417, 77562.26032466823, 77472.45724727474]

# %%
def do_best_ndcg():
    mae_errors = []
    ndcg_scores = []

    for _train, _test in tqdm_notebook(skf.split(pd_train.index, pd_train.label), total=3):
        i_test = pd_train.iloc[_test].copy().sort_values(["context_id", "label"], ascending=[True, False])
        
        Y_test = i_test.sort_values(["context_id", "label"], ascending=[True, False]).label.values
        Y_predict = i_test.sort_values(["context_id", "label"], ascending=[True, False]).label.values
        
        mae_errors.append(mean_absolute_error(Y_test, Y_predict))
        ndcg_scores.append(calc_ndcg_score(i_test, Y_predict))

    print(mae_errors)
    print(ndcg_scores)
do_best_ndcg()
# Out:
# A Jupyter Widget
# [0.0, 0.0, 0.0]
# [100000.0, 100000.0, 100000.0]

# %% [markdown]
# # Submit

# %%
def do_submit(submission_name, model_reg, to_features, to_target):
    i_train = pd_train
    i_test = pd_public.copy()

    X_train = to_features(i_train)
    X_test = to_features(i_test)
    Y_train = to_target(i_train)

    model_reg.fit(X_train, Y_train)
    Y_predict = model_reg.predict(X_test)

    i_test["predict"] = Y_predict
    i_test.sort_values(["context_id", "predict"], ascending=[True, False], inplace=True)

    i_test.head(15)
    i_test[["context_id", "reply_id"]].to_csv(submission_name, index=False, header=False, sep="\t")
    
    return i_test

# %%
fit_tfidf(analyzer="char", ngram_range=(3, 4))
do_submit("linear_cv_opsion.tsv", Ridge(alpha=20.0), to_features_tfidf, trg_label_confidence)
# Out:
#            context_id                                          context_2  \
# 3479  100097508986637
# 3478  100097508986637
# 3476  100097508986637
# 3480  100097508986637
# 3475  100097508986637
# 3477  100097508986637
# 3483  100149747456986
# 3482  100149747456986
# 3484  100149747456986
# 3486  100149747456986
# 3481  100149747456986
# 3485  100149747456986
# 3491  100441828256276                                       я чувствую !
# 3489  100441828256276                                       я чувствую !
# 3492  100441828256276                                       я чувствую !
# 3490  100441828256276                                       я чувствую !
# 3487  100441828256276                                       я чувствую !
# 3488  100441828256276                                       я чувствую !
# 3497  100447631007679                                  просто прекрати !
# 3493  100447631007679                                  просто прекрати !
# 3498  100447631007679                                  просто прекрати !
# 3495  100447631007679                                  просто прекрати !
# 3496  100447631007679                                  просто прекрати !
# 3494  100447631007679                                  просто прекрати !
# 3500  100696807089944
# 3499  100696807089944
# 3502  100696807089944
# 3501  100696807089944
# 3504  100696807089944
# 3503  100696807089944
# ...               ...                                                ...
# 3449   99068729200925                             мой князь зовет меня .
# 3446   99068729200925                             мой князь зовет меня .
# 3447   99068729200925                             мой князь зовет меня .
# 3448   99068729200925                             мой князь зовет меня .
# 3445   99068729200925                             мой князь зовет меня .
# 3450   99068729200925                             мой князь зовет меня .
# 3453   99159608087191
# 3456   99159608087191
# 3451   99159608087191
# 3454   99159608087191
# 3452   99159608087191
# 3455   99159608087191
# 3459   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3461   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3462   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3458   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3457   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3460   99269586001865  вы мне начали рассказывать , рядом с каким мус...
# 3463   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3465   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3464   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3466   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3468   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3467   99555374975567  я и секретарь службы безопасности , обсудили ,...
# 3473   99556658565013
# 3472   99556658565013
# 3469   99556658565013
# 3474   99556658565013
# 3471   99556658565013
# 3470   99556658565013
#
#                                               context_1  \
# 3479
# 3478
# 3476
# 3480
# 3475
# 3477
# 3483                           как вы здесь оказались ?
# 3482                           как вы здесь оказались ?
# 3484                           как вы здесь оказались ?
# 3486                           как вы здесь оказались ?
# 3481                           как вы здесь оказались ?
# 3485                           как вы здесь оказались ?
# 3491                          по этой причине я здесь .
# 3489                          по этой причине я здесь .
# 3492                          по этой причине я здесь .
# 3490                          по этой причине я здесь .
# 3487                          по этой причине я здесь .
# 3488                          по этой причине я здесь .
# 3497                            прекрати спасать меня .
# 3493                            прекрати спасать меня .
# 3498                            прекрати спасать меня .
# 3495                            прекрати спасать меня .
# 3496                            прекрати спасать меня .
# 3494                            прекрати спасать меня .
# 3500                                дайсон любит тебя .
# 3499                                дайсон любит тебя .
# 3502                                дайсон любит тебя .
# 3501                                дайсон любит тебя .
# 3504                                дайсон любит тебя .
# 3503                                дайсон любит тебя .
# ...                                                 ...
# 3449             он движется через моря к своему дому .
# 3446             он движется через моря к своему дому .
# 3447             он движется через моря к своему дому .
# 3448             он движется через моря к своему дому .
# 3445             он движется через моря к своему дому .
# 3450             он движется через моря к своему дому .
# 3453  я нахожу , что прогулка после приёма пищи помо...
# 3456  я нахожу , что прогулка после приёма пищи помо...
# 3451  я нахожу , что прогулка после приёма пищи помо...
# 3454  я нахожу , что прогулка после приёма пищи помо...
# 3452  я нахожу , что прогулка после приёма пищи помо...
# 3455  я нахожу , что прогулка после приёма пищи помо...
# 3459         д - да , это сложно объяснить на пальцах .
# 3461         д - да , это сложно объяснить на пальцах .
# 3462         д - да , это сложно объяснить на пальцах .
# 3458         д - да , это сложно объяснить на пальцах .
# 3457         д - да , это сложно объяснить на пальцах .
# 3460         д - да , это сложно объяснить на пальцах .
# 3463                      ћы расскажем просто и пр€мо .
# 3465                      ћы расскажем просто и пр€мо .
# 3464                      ћы расскажем просто и пр€мо .
# 3466                      ћы расскажем просто и пр€мо .
# 3468                      ћы расскажем просто и пр€мо .
# 3467                      ћы расскажем просто и пр€мо .
# 3473                               да , хороший выбор .
# 3472                               да , хороший выбор .
# 3469                               да , хороший выбор .
# 3474                               да , хороший выбор .
# 3471                               да , хороший выбор .
# 3470                               да , хороший выбор .
#
#                                               context_0 reply_id  \
# 3479                                        выключай их        4
# 3478                                        выключай их        3
# 3476                                        выключай их        1
# 3480                                        выключай их        5
# 3475                                        выключай их        0
# 3477                                        выключай их        2
# 3483                              не надо меня тянуть !        2
# 3482                              не надо меня тянуть !        1
# 3484                              не надо меня тянуть !        3
# 3486                              не надо меня тянуть !        5
# 3481                              не надо меня тянуть !        0
# 3485                              не надо меня тянуть !        4
# 3491                                мой духовный путь !        4
# 3489                                мой духовный путь !        2
# 3492                                мой духовный путь !        5
# 3490                                мой духовный путь !        3
# 3487                                мой духовный путь !        0
# 3488                                мой духовный путь !        1
# 3497              в чем , черт возьми , твоя проблема ?        4
# 3493              в чем , черт возьми , твоя проблема ?        0
# 3498              в чем , черт возьми , твоя проблема ?        5
# 3495              в чем , черт возьми , твоя проблема ?        2
# 3496              в чем , черт возьми , твоя проблема ?        3
# 3494              в чем , черт возьми , твоя проблема ?        1
# 3500                                              нет .        1
# 3499                                              нет .        0
# 3502                                              нет .        3
# 3501                                              нет .        2
# 3504                                              нет .        5
# 3503                                              нет .        4
# ...                                                 ...      ...
# 3449                   там он снова обретет свою силу .        4
# 3446                   там он снова обретет свою силу .        1
# 3447                   там он снова обретет свою силу .        2
# 3448                   там он снова обретет свою силу .        3
# 3445                   там он снова обретет свою силу .        0
# 3450                   там он снова обретет свою силу .        5
# 3453                                      кто со мной ?        2
# 3456                                      кто со мной ?        5
# 3451                                      кто со мной ?        0
# 3454                                      кто со мной ?        3
# 3452                                      кто со мной ?        1
# 3455                                      кто со мной ?        4
# 3459  хорошо , кевин , дело в том что . . . вы арест...        2
# 3461  хорошо , кевин , дело в том что . . . вы арест...        4
# 3462  хорошо , кевин , дело в том что . . . вы арест...        5
# 3458  хорошо , кевин , дело в том что . . . вы арест...        1
# 3457  хорошо , кевин , дело в том что . . . вы арест...        0
# 3460  хорошо , кевин , дело в том что . . . вы арест...        3
# 3463     ћы расскажем о самой большой тайне в истории .        0
# 3465     ћы расскажем о самой большой тайне в истории .        2
# 3464     ћы расскажем о самой большой тайне в истории .        1
# 3466     ћы расскажем о самой большой тайне в истории .        3
# 3468     ћы расскажем о самой большой тайне в истории .        5
# 3467     ћы расскажем о самой большой тайне в истории .        4
# 3473                                              что ?        4
# 3472                                              что ?        3
# 3469                                              что ?        0
# 3474                                              что ?        5
# 3471                                              что ?        2
# 3470                                              что ?        1
#
#                                                   reply   predict
# 3479                                    пытаюсь , сэр .  0.345558
# 3478                                        я пытаюсь !  0.162357
# 3476              ты не выключишь , тогда € сам выключу -0.021206
# 3480                                          выключите -0.270745
# 3475                                    выключить что ? -0.284118
# 3477                                        выключить ? -0.332019
# 3483                     я не могу позволить вам уйти .  0.304185
# 3482                  мне показалось , вы меня зовете .  0.258659
# 3484                                    мне уже легче .  0.219066
# 3486                   что " не надо " ? не надо меня .  0.054430
# 3481                                            ладно .  0.047574
# 3485                                         извините . -0.061571
# 3491                                   мой повешенный .  0.260258
# 3489   иным бог шепчет в уши . мне же он кричит в них !  0.243701
# 3492                                уильям , довольно .  0.146524
# 3490                                            и мой .  0.120970
# 3487                                нет никакого бога .  0.068058
# 3488                                              мой . -0.069289
# 3497                   ты знаешь , в чем моя проблема ?  0.349712
# 3493                               у меня нет проблем .  0.313264
# 3498              ты должен быть дать мне это уладить .  0.296484
# 3495                              у меня нет проблемы .  0.294143
# 3496                                      проблем нет .  0.245227
# 3494                                           в тебе .  0.121033
# 3500  я знаю ты любишь его , и я знаю , ты скучаешь ...  0.310679
# 3499                                       почему нет ?  0.186733
# 3502                                       поверь мне .  0.050611
# 3501                                           правда .  0.009082
# 3504                                       а вот и да . -0.057405
# 3503                                          что нет ? -0.240047
# ...                                                 ...       ...
# 3449  он может защитить нас , и я знаю , что марсель...  0.469623
# 3446    за ним последуют еще трое и тогда он начнется .  0.371769
# 3447  сперва такая милая , но в следующее мгновение ...  0.338255
# 3448  но по самой природе вещей он не может не оказа...  0.271109
# 3445                         но его пистолет был пуст .  0.097722
# 3450                    бедному сердцу так говорил он .  0.063493
# 3453                                     да , конечно .  0.384324
# 3456                              рассчитывай на меня .  0.237858
# 3451                                            никто . -0.054465
# 3454                                                  ! -0.138472
# 3452                                               мы ! -0.222396
# 3455                                                я ! -0.242453
# 3459  я знаю , в чем меня обвиняют , и я один несу о...  0.254739
# 3461  разговаривал со мной и другими ребятами в суде...  0.235786
# 3462  на прошлой неделе он был зачислен в международ...  0.234368
# 3458          однако свидетель обязан говорить правду .  0.174217
# 3457  я признаю , что доказательств против этих свид...  0.100274
# 3460                       мы предоставили суду залог .  0.014412
# 3463  вы им всё расскажете , потому что вас будут пы...  0.449332
# 3465        расследование будет продолжаться до конца .  0.323794
# 3464                    у отца всегда все засекречено .  0.075516
# 3466     ћы расскажем о самой большой тайне в истории .  0.065803
# 3468        и вы назначили меня в секретные материалы .  0.032561
# 3467                                    я не источник . -0.046474
# 3473                                  ничего , забудь .  0.061452
# 3472                                     нет , ничего .  0.060133
# 3469                                  твоя фотография . -0.133864
# 3474                                           ничего . -0.136778
# 3471                                       твой кулон . -0.181642
# 3470                                              это . -0.199305
#
# [9968 rows x 7 columns]
